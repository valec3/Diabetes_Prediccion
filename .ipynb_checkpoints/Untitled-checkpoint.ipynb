# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np#Linear Algebra
import seaborn as sns#visualization
import matplotlib.pyplot as plt#visualization
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.graph_objs as go
import plotly.offline as py
# %pylab inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_excel('./BD-diabetes-Pima.xlsx',sheet_name="Muestra") 
df.drop('n', axis=1, inplace=True)

# %%
df.head()
# Out:
#    # DE ENBARAZOS  GLUCOSA  PRESION SANGUINEA  GROSOR DE PIEL  INSULINA  \
# 0               6      103                 72              32       190
# 1               7      103                 66              32         0
# 2               1      119                 44              47        63
# 3               0       93                 60              25        92
# 4               1      126                 56              29       152
#
#   INSULINA (BI)   BMI  DiabetesPedigreeFunction  EDAD  Outcome
# 0            SI  37.7                     0.324    55        0
# 1            NO  39.1                     0.344    31        1
# 2            SI  35.5                     0.280    25        0
# 3            SI  28.7                     0.532    22        0
# 4            SI  28.7                     0.801    21        0

# %% [markdown]
# ## Analisis Exploratorio

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# # DE ENBARAZOS            680.0    3.895588    3.403106   0.000   1.00000
# GLUCOSA                   680.0  119.608824   33.680819   0.000  99.00000
# PRESION SANGUINEA         680.0   72.300000   11.875322  24.000  64.00000
# GROSOR DE PIEL            680.0   22.385294   15.705175   0.000  10.00000
# INSULINA                  680.0   82.277941  114.270217   0.000   0.00000
# BMI                       680.0   32.508971    7.463551   0.000  27.70000
# DiabetesPedigreeFunction  680.0    0.489062    0.351372   0.078   0.24675
# EDAD                      680.0   33.598529   11.950154  21.000  24.00000
# Outcome                   680.0    0.341176    0.474454   0.000   0.00000
#
#                               50%      75%     max
# # DE ENBARAZOS              3.000    6.000   17.00
# GLUCOSA                   117.000  140.000  199.00
# PRESION SANGUINEA          72.000   80.000  114.00
# GROSOR DE PIEL             25.000   33.000   99.00
# INSULINA                   42.500  130.000  680.00
# BMI                        32.200   37.200   59.40
# DiabetesPedigreeFunction    0.388    0.654    2.42
# EDAD                       29.000   41.000   69.00
# Outcome                     0.000    1.000    1.00

# %%
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   # DE ENBARAZOS            680 non-null    int64
#  1   GLUCOSA                   680 non-null    int64
#  2   PRESION SANGUINEA         680 non-null    int64
#  3   GROSOR DE PIEL            680 non-null    int64
#  4   INSULINA                  680 non-null    int64
#  5   INSULINA (BI)             680 non-null    object
#  6   BMI                       680 non-null    float64
#  7   DiabetesPedigreeFunction  680 non-null    float64
#  8   EDAD                      680 non-null    int64
#  9   Outcome                   680 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 53.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   # DE ENBARAZOS            680 non-null    int64
#  1   GLUCOSA                   680 non-null    int64
#  2   PRESION SANGUINEA         680 non-null    int64
#  3   GROSOR DE PIEL            680 non-null    int64
#  4   INSULINA                  680 non-null    int64
#  5   INSULINA (BI)             680 non-null    object
#  6   BMI                       680 non-null    float64
#  7   DiabetesPedigreeFunction  680 non-null    float64
#  8   EDAD                      680 non-null    int64
#  9   Outcome                   680 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 53.2+ KB

# %%
p = df.hist(figsize = (20,20))

# %%
color_wheel = {1: "#0392cf", 
               2: "#7bc043"}
colors = df["Outcome"].map(lambda x: color_wheel.get(x + 1))
print(df.Outcome.value_counts())
p=df.Outcome.value_counts().plot(kind="bar")
# Out:
# 0    448
# 1    232
# Name: Outcome, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21232\316040624.py in <module>
#       3 colors = df["Outcome"].map(lambda x: color_wheel.get(x + 1))
#       4 print(df.Outcome.value_counts())
# ----> 5 p=df.RESULTADO.value_counts().plot(kind="bar")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'RESULTADO'
